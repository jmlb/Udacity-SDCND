# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
# Import everything needed to edit/save/watch video clips
from moviepy.editor import VideoFileClip
from IPython.display import HTML
# %matplotlib inline

src_pts = np.float32([[200, 710], [520, 500], [770, 500], [1110, 710]])
dst_pts = np.float32([[320, 720], [320, 20], [970, 20], [960, 720]])
birdview_pts = {'src_pts': src_pts, 'dst_pts': dst_pts}


def display(img, title, color=1):
    '''
    display images
    img: rgb or grayscale
    title: figure title
    color: show image in color(1) or grasycale(0)
    '''
    if color:
        plt.imshow(img)
    else:
        plt.imshow(img, cmap='gray')
    plt.title(title)
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Camera Calibration

# %%
def camera_calibration(folder, nx, ny, showMe=0):
    '''
    find all the location of all corners (x, y, z) with z=0
    using openCV findChessBoardCorners
    return a dictionary:
        ret: True/False if corners were detected by openCV findChessboardCorners
        imagePoints: coordinate of corners detected in all images
        objectPoints: coordinate of corners in destination image (x, y, z)
        img_sz: size of image (width, height)
        ''
        run calibration using corners[ret, imgPoints, objPoints, img_sz] found in all images
        return:
            ret: RMSError of calibration
            mtx: Camera Matrix
            dist: distorsion coefficient
            rotationVec: rotation vecteurs
            tvecs: translation vectors
    '''
    # Store object points and image points from all the images
    objpoints = [] #3D points in real world space
    imgpoints = [] #2D points in image plane
    #Prepare object points, like (0,0,0), (1, 0,0)
    objp = np.zeros((nx * ny, 3), np.float32)
    objp[:,:2] = np.mgrid[0:nx,0:ny].T.reshape(-1,2) #x, y coordinate
        
    assert len(folder) != 0, 'No file found in folder'
        
    for fname in folder:
        img = cv2.imread(fname)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        ret, corners = cv2.findChessboardCorners(gray, (nx, ny), None)
        img_sz = gray.shape[::-1]
            
        if ret:
            imgpoints.append(corners)
            objpoints.append(objp)
            if showMe:
                draw_corners = cv2.drawChessboardCorners(img, (nx, ny), corners, ret)
                display(draw_corners, 'Found all corners: {} '.format(ret))

    if len(objpoints) == len(imgpoints) and len(objpoints) != 0:
        print('ok')
        ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, img_sz, None, None)
        return {'ret': ret, 'cameraMatrix': mtx, 'distorsionCoeff': dist, \
                    'rotationVec': rvecs, 'translationVec': tvecs}
    else:
        raise Error('Camera Calibration failed')


        
nx = 9 #number of corners in a row
ny = 6 #numbers or corners in a column
folder_calibration = glob.glob("camera_cal/calibration*.jpg") #list of chessboard image file
calib_params = camera_calibration(folder_calibration, nx, ny, showMe=1)
# for a good calibration ret must be between 0.1 and 1.0
print('RMS Error of Camera calibration: {:.3f}'.format(calib_params['ret']) )
print('This number must be between 0.1 and 1.0')
# Out:
# ok
# RMS Error of Camera calibration: 1.187
# This number must be between 0.1 and 1.0

# %% [markdown]
# # Image processing

# %%
class ImageProcess():
    '''
    Processing methods of original images
    '''
    def __init__(self, image):
        self.image = image
    
    
    def undistort(self, calib_params, showMe=0):
        undistorted = cv2.undistort(self.image, calib_params['cameraMatrix'], calib_params['distorsionCoeff'], None, 
                         calib_params['cameraMatrix'])
        if showMe:
            display(image, 'Original', color=1)
            display(corrected, 'After correction', color=1)
        return undistorted

    
    def gaussianBlur(self, img, k_sz):
        k_sz = 5
        img = cv2.GaussianBlur(img, (k_sz, k_sz), 0)
        return img
    
    
    def directional_gradient(self, img, direction='x', thresh=[0, 255]):
        '''
        Gradient along vertical or horizontal direction using OpenCV Sobel 
        img: RGB or Grayscale image
        direction: x(horizontal) or y(vertical) for gradient direction
        thresh: apply threshold on pixel intensity of gradient image
        ksize: kernel size (can only be a odd number)
        output is a binary image
        '''
        if direction == 'x':
            sobel = cv2.Sobel(img, cv2.CV_64F, 1, 0)
        elif direction == 'y':
            sobel = cv2.Sobel(img, cv2.CV_64F, 0, 1)
        
        sobel_abs = np.absolute(sobel)  #absolute value
        scaled_sobel = np.uint8(sobel_abs * 255/np.max(sobel_abs)) #turn sobel to 8bit image 0-255 intensity range
        binary_output = np.zeros_like(sobel)
        binary_output[(scaled_sobel>= thresh[0]) & (scaled_sobel <= thresh[1]) ] = 1 #generate binary
        
        return binary_output


    def mag_gradient(self, img, thresh=[0, 255]):
        '''
        Magnitude of gradient : sqrt(gradx**2 + grady**2)
        img: RGB or Grayscale image
        thresh: apply threshold on pixel intensity of the gardient magnitude
        ksize: kernel size (can only be a odd number)
        output is a binary image
        '''
        sobelx = cv2.Sobel(img, cv2.CV_64F, 1, 0)  #gradient along x
        sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1) #gradient along y
        gradient_mag = np.sqrt( np.square(sobelx) + np.square(sobely)) # norm of gradient
        scaled_gradient_mag = np.uint8(gradient_mag * 255/np.max(gradient_mag)) #turn sobel to 8bit image 0-255 intensity range
        binary_output = np.zeros_like(gradient_mag)
        binary_output[(scaled_gradient_mag >= thresh[0]) & (scaled_gradient_mag <= thresh[1]) ] = 1 #thresholding
        
        return binary_output


    def gradient_direction(self, img, thresh=[0, 90], ksize=3):
        '''
        Direction of gradient: arctan(grady/gradx)
        img: RGB or Grayscale image
        thresh: apply threshold on gradient direction in degrees (0, 90)
        ksize: kernel size (can only be a odd number)
        output is a binary image
        '''
        sobelx = cv2.Sobel(img, cv2.CV_64F, 1,0, ksize) #gradient along x
        sobely = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize) #gradient along y
        gradient_dir = np.arctan2( sobely, sobelx)
        thresh = [thresh[0] * np.pi/180, thresh[1] * np.pi/180] #convert threshold from degree to radian
        binary_output = np.zeros_like(gradient_dir)
        binary_output[(gradient_dir>= thresh[0]) & (gradient_dir <= thresh[1]) ] = 1 #thresholding
        
        return binary_output

    
    def color_binary(self, img, dst_format='HLS', ch=2, ch_thresh=[0,255]):
        '''
        Color thesholding on channel 2 and 3
        img: RGB
        dst_format: destination format (HLS or HSV)
        ch2_thresh: pixel intensity threshold on channel 2
        ch3_thresh: pixel intensity threshold on channel 3
        output is a binary image
        '''
        if dst_format == 'HSV':
            img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
            ch_binary = np.zeros_like(img[:,:, int(ch-1)])
        else:
            img = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
            ch_binary = np.zeros_like(img[:,:, int(ch-1)])
            ch_binary[(img[:,:,int(ch-1)] >= ch_thresh[0]) & (img[:,:,int(ch-1)]<= ch_thresh[1])] = 1
        
        return ch_binary
    
    
    
    def image_correction(self, img, cal_params):
        '''
        correct image from camera distorsion
        img: original image RGB format
        cal_params: calibration parameters of camera
        return: undistorted image
        '''
        dst = cv2.undistort(img, cal_params['cameraMatrix'], \
                            cal_params['distorsionCoeff'], None, \
                            cal_params['cameraMatrix'])
        return dst
        
    
    def convert2_rgb(self, img):
        '''
        convert image to RGB
        img: RGB image
        '''
        try:
            rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            return rgb
        except:
            print('image cannpot be converted to RGB')
    
    
    def convert2_gray(self, img):
        '''
        convert image to gray
        img: RGB image
        '''
        if len(img.shape) == 3:
            gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
            return gray
        elif len(img.shape) == 2: #img channel already squashed
            return img

    
    def birdView(self, img, birdview_pts):
        '''
        Transform image to birdview
        birdview_pts: dict with 
                    * src_pts: source points (points in original image)
                    * dst_pts: destination points (points in birdview image)
        '''
        M = cv2.getPerspectiveTransform(birdview_pts['src_pts'], birdview_pts['dst_pts'])
        Minv = cv2.getPerspectiveTransform(birdview_pts['dst_pts'], birdview_pts['src_pts'])
        img_sz = (img.shape[1], img.shape[0])
        img_warped = cv2.warpPerspective(img, M, img_sz, flags=cv2.INTER_LINEAR)
        
        return (img_warped, Minv)

# %%
import matplotlib.patches as patches
from scipy.optimize import curve_fit


class FindingLanes():
    '''
    extract pixels associated with lanes and fit them to 2nd order polynomial function
    '''
    
    def __init__(self, image, bottom_crop, sliding_window, hot_pixel_thresh):
        self.image = image
        self.bottom_crop = bottom_crop
        self.hot_pixel_thresh = hot_pixel_thresh
        self.sliding_window = sliding_window
        #adjust image height (remove front-end of car)
        self.image = self.image[0:self.bottom_crop, :]
    
    def polynomial_fit(self, data):
        '''
        Perform 2nd order polynomial fit: a0 + a1 x + a2 x**2
        data: dictionary with x and y values {'var':[], 'output':[]}
        '''
        a2, a1, a0 = np.polyfit(data['var'], data['output'], 2)
        return {'a0': a0, 'a1': a1, 'a2': a2}


        
    def find_starter_centroids(self, hot_pixel_thresh):
        '''
        Find starter centroids (for left and right lane) using histogram of bottom half of the image 
        hot_pixel_thresh: If peak intensity is below a threshold use histogram on the full height of the image
        returns left and right centroid position
        '''
        window_l = {'x0': 0, 'y0': self.image.shape[0], 
                    'width':self.image.shape[1]/2, 'height':self.image.shape[0]/2}
        centroid_l, hot_pixel_cnt_l = self.find_centroid(window_l)
        if (hot_pixel_cnt_l < hot_pixel_thresh):
            window_l['height']=self.image.shape[0]
            centroid_l, hot_pixel_cnt_l = self.find_centroid(window_l)
            
        window_r = {'x0': self.image.shape[1]/2, 'y0': self.image.shape[0], 'width':self.image.shape[1]/2, 
                    'height':self.image.shape[0]/2}
        centroid_r, hot_pixel_cnt_r = self.find_centroid(window_r)
        
        if (hot_pixel_cnt_r < hot_pixel_thresh):
            window_r['height']=self.image.shape[0]
            centroid_r, hot_pixel_cnt_r = self.find_centroid(window_r)
        #only interested in rough estimate of the line
        return {'left': [centroid_l, hot_pixel_cnt_l], 'right':[centroid_r, hot_pixel_cnt_r]}

    
    
    def find_centroid(self, window, showMe=0):
        '''
        find centroid in window using histogram of pixels within the window
        img: binary image
        window: dict({'x0', 'y0', 'width', 'height'})
        display if hotpixel_cnt (number of pixel in window is smaller than a threshold, 
        take centroid as center of window)
        '''
        #crop image to window dimension
        crop_image = self.image[ round( window['y0'] - window['height']):round(window['y0']), 
                              round(window['x0']):round(window['x0']+ window['width'])]
        histogram = np.sum(crop_image, axis=0)
        if showMe:
            plt.plot(histogram)
            plt.title('Histogram')
            plt.show()
        hot_pixel_cnt = np.sum(histogram)
        if hot_pixel_cnt > self.hot_pixel_thresh:
            try:
                centroid = np.argmax(histogram)
            except:
                print('Centroid not found!')
            centroid = int( round(centroid + window['x0']) )
        
        else:
            #take center of box as new centroid ()
            centroid = int( round(window['x0'] + window['width']/2) )  
        
        return (centroid, hot_pixel_cnt)   
    
 
    def run_sliding_window(self, centroid_starter_l, centroid_starter_r, showMe=0):
        '''
        Run sliding window from bottom of image to top and return indexes of the hot pixels associated with lane
        centroi_starter_l: centroid starting location for left lane
        centroid_starter_r: centroid starting location for right lane
        '''
        #Initialize window for left and right lane
        window_l = {'x0': centroid_starter_l - int(self.sliding_window['width']/2), 'y0': self.image.shape[0],
                 'width': self.sliding_window['width'], 
                  'height': round(self.image.shape[0]/self.sliding_window['n_steps'])}

        window_r = {'x0': centroid_starter_r - int(self.sliding_window['width']/2), 'y0': self.image.shape[0],
                 'width': self.sliding_window['width'], 
                  'height': round(self.image.shape[0]/self.sliding_window['n_steps'])}
        
        #Initialize dict to store (var_height, output=f(var)) coordinate of hotpixels and centroid location after all sliding window steps
        #at each step of sliding window
        #
        hotpixels_log = { 'left': {'var': [], 'output':[]}, 'right': {'var':[], 'output':[]} }
        centroids_log = {'left': [], 'right': []}
        if showMe:
            out_img = (np.dstack((self.image, self.image, self.image) ) * 255).astype('uint8') #convert to uint8
        
        for step in range(self.sliding_window['n_steps']):
            
            #Limit lateral position of box, must remain within image width
            if (window_l['x0'] < 0): window_l['x0'] = 0   
            if (window_r['x0'] + window_r['width']) > self.image.shape[1]: 
                window_r['x0'] = self.image.shape[1] - window_r['width']
            
            centroid_r, _ = self.find_centroid(window_r)
            centroid_l, _ = self.find_centroid(window_l)
            
            # Create a copy of image where all pixels outside right/left lane window are turn off (=0)
            masked_l = np.zeros_like(self.image)
            masked_l[ window_l['y0']- window_l['height'] : window_l['y0'],
                                window_l['x0']:window_l['x0']+window_l['width']] \
                    = self.image[ window_l['y0']- window_l['height'] : window_l['y0'],
                                window_l['x0']:window_l['x0']+window_l['width']]
            
            masked_r = np.zeros_like(self.image)
            masked_r[ window_r['y0']- window_r['height'] : window_r['y0'],
                                window_r['x0']:window_r['x0']+window_r['width']] \
                    = self.image[window_r['y0']- window_r['height'] : window_r['y0'],
                                window_r['x0']:window_r['x0']+window_r['width']]
                
            
            #Get coordinates of hot pixels in left/right window
            hot_pixels_l = np.nonzero( masked_l )
            hot_pixels_r = np.nonzero( masked_r )
            
            #Do not record pixels if total count of hotpixels below thresh
            if len(hot_pixels_l[0]) >= self.hot_pixel_thresh:
                hotpixels_log['left']['var'].extend(hot_pixels_l[0].tolist())
                hotpixels_log['left']['output'].extend(hot_pixels_l[1].tolist())
            
            if len(hot_pixels_r[0]) >= self.hot_pixel_thresh:
                hotpixels_log['right']['var'].extend(hot_pixels_r[0].tolist())
                hotpixels_log['right']['output'].extend(hot_pixels_r[1].tolist()) 
           
            #Draw windows
            if showMe:
                cv2.rectangle(out_img, 
                          (window_l['x0'], window_l['y0']- window_l['height']),
                          (window_l['x0']+window_l['width'], window_l['y0']),(0,255,0), 2)
                cv2.rectangle(out_img, 
                          (window_r['x0'], window_r['y0']- window_r['height']),
                          (window_r['x0']+window_r['width'], window_r['y0']),(0,0,255), 2)
                plt.imshow(out_img)
                plt.show()
            #update record of centroids
            centroids_log['left'].append([centroid_l, window_l['y0']])
            centroids_log['right'].append([centroid_r, window_r['y0']])
            #window next position
            window_l['x0'] = round(centroid_l - window_l['width']/2)
            window_l['y0'] = window_l['y0'] - window_l['height']
            window_r['x0'] = round(centroid_r - window_r['width']/2)
            window_r['y0'] = window_r['y0'] - window_r['height']
        
        return hotpixels_log

# %%
# Image preparation pipeline
def image_process_pipeline(image, camera_calib, k_blur, gradx_thresh=[0, 255], 
                     ch_thresh=[0, 255], showMe=0):
    '''
    Image processing to highlight lanes
    image: image BGR format (OpenCV)
    camera_calib: calibration parameters of camera
    birdview_pts: source and destination points
    showMe: if True show images at each process step
    '''

    process = ImageProcess(image)
    
    image = process.image_correction(image, camera_calib)
    if showMe: display(image, 'Apply Camera Correction', color=1)
        
    #Gaussian Blur: Noise removal
    #image = process.gaussianBlur(image, k_blur)
    #if showMe: display(image, 'Gaussian Blur', color=1)
    
    gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    if showMe: display(gray, 'GRAY', color=0)
        
    gradx = process.directional_gradient(gray, direction='x', thresh=gradx_thresh )
    if showMe: display(gradx, 'Gradient x', color=0)
    
    ch3_hls_binary = process.color_binary(image, dst_format='HLS', ch=3, ch_thresh=ch_thresh)
    if showMe: display(ch3_hls_binary, 'HLS to Binary S ', color=0)
        
    ch3_hls_grad = process.directional_gradient(ch3_hls_binary, direction='x', thresh=gradx_thresh )
    if showMe: display(gradx, 'Gradient x HLS', color=0)
    
    combined_gradx = np.zeros_like(gradx)
    combined_gradx[((gradx == 1) | (ch3_hls_grad == 1) )] = 1
    if showMe: display(combined_gradx, 'Combined Gradient x of HLS and Gray', color=0)
        
    combined_output = np.zeros_like(gradx)
    combined_output[((combined_gradx == 1) | (ch3_hls_binary == 1) )] = 1
    if showMe: display(combined_output, 'Combined output', color=0)
    
    output_warped, Minv = process.birdView(combined_output, birdview_pts)
    if showMe: display(output_warped, 'Bird View', color=0)
        
    return (output_warped, Minv)




def pipeline_predict_lanes(input_image, showMe=0):
    
    k_blur = 5
    sliding_window_specs = {'width': 80, 'n_steps': 9}
    bottom_crop = -60 #front-end car
    sliding_window_specs = {'width': 80, 'n_steps': 9} #number of steps vertical steps of sliding window
    hot_pixel_thresh = 100 # if number of hot pixel in window below 50, #consider them as noise and do not attempt to get centroid
    
    img_sz = (input_image.shape[1], input_image.shape[0])
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/700 # meters per pixel in x dimension
    #birdview_pts = {'src_pts': src_pts, 'dst_pts': dst_pts}
    #input_image = cv2.imread('test_images/straight_lines1.jpg')
    ref_point_radius = input_image.shape[0]

    draw_lane_thickness = 20 #hwo thick to draw predicted lanes in px
    input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
    # Run image processing pipeline
    input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
    warped_img, Minv = image_process_pipeline(input_image, calib_params, k_blur,
                                gradx_thresh=[25, 255], 
                                ch_thresh=[170, 255],
                                showMe=0)
    #Run lane finding
    lanes = FindingLanes(warped_img, bottom_crop, sliding_window_specs, hot_pixel_thresh)
    #hot_pixel_thresh : if the half window contain hot pixel below the threshold, take histogram on full height
    centroid_starters = lanes.find_starter_centroids(hot_pixel_thresh=50)
    centroid_starter_right = centroid_starters['right']
    centroid_starter_left = centroid_starters['left']
    # record left/right lane hotpixels coordinates x and y
    hotpixels_log = lanes.run_sliding_window(centroid_starter_left[0], centroid_starter_right[0])
    fit_left = lanes.polynomial_fit(hotpixels_log['left'])
    fit_right = lanes.polynomial_fit(hotpixels_log['right'])
    #Get predicted lanes position as a function of height
    var_pts = np.linspace(0, warped_img.shape[0]-1, num=warped_img.shape[0]) #x-axis (height) points
    #predicted left lane
    pred_leftLane = fit_left['a2']*var_pts**2 + fit_left['a1']*var_pts + fit_left['a0']
    pred_rightLane = fit_right['a2']*var_pts**2 + fit_right['a1']*var_pts + fit_right['a0'] 
    
    if showMe:
        #display lane and best polynomial fits
        plt.imshow(warped_img, cmap='gray')
        plt.plot(pred_leftLane, var_pts, 'b-')
        plt.plot(pred_rightLane, var_pts, 'r-')
        plt.show()
    
    
    ###############
    # Draw line prediction/fit as thick lines
    h_pts = np.concatenate((var_pts, var_pts[::-1]), axis=0)
    left_lane = np.concatenate((pred_leftLane - draw_lane_thickness, pred_leftLane[::-1]+draw_lane_thickness), axis=0)
    l = np.array(list(zip(left_lane, h_pts)), np.int32)
    right_lane = np.concatenate((pred_rightLane - draw_lane_thickness, pred_rightLane[::-1]+draw_lane_thickness), axis=0)
    r = np.array(list(zip(right_lane, h_pts)), np.int32)
    road = np.zeros_like(input_image)
    cv2.fillPoly(road, [l], color=[255, 0, 0])
    cv2.fillPoly(road, [r], color=[255, 0, 0])
    img_size = (input_image.shape[1], input_image.shape[0])

    road_warped = cv2.warpPerspective(road, Minv, img_size, flags=cv2.INTER_LINEAR)
    result = cv2.addWeighted(cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB), 0.9, road_warped, 1.0, 0.0)
    
    
    ###############
    # estimate offsetclose to driver (bottom of image)
    print('***************************', pred_leftLane[-1])
    camera_center = (pred_leftLane[-1] +  pred_rightLane[-1])/2
    center_offset = (camera_center - warped_img.shape[1]/2) * xm_per_pix
    side_pos = 'left'
    if center_offset < 0:
        side_pos = 'right'
    
    cv2.putText(result, 'Vehicle is '+ str(round(center_offset, 3)) +'m ' +side_pos +'of center',
                (50, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255))
    
    ##############
    # Radius of Curvature
    # Determine polynomial parameters in real space
    real_space_pred_leftLane = lanes.polynomial_fit({'var': np.array(hotpixels_log['left']['var'])*xm_per_pix, 
                                                     'output': np.array(hotpixels_log['left']['output'])*ym_per_pix})
    
    real_space_pred_rightLane = lanes.polynomial_fit({'var': np.array(hotpixels_log['right']['var'])*xm_per_pix, 
                                                     'output': np.array(hotpixels_log['right']['output'])*ym_per_pix})
    
    # Calculate radii of curvature real space at point ref_point = bottom of image
    left_radius = ((1 + (2*real_space_pred_leftLane['a2']*ref_point_radius *ym_per_pix + real_space_pred_leftLane['a1'])**2)**1.5) \
                        / np.absolute(2*fit_left['a2'])
    
    right_radius = ((1 + (2*real_space_pred_rightLane['a2']*ref_point_radius*ym_per_pix + real_space_pred_rightLane['a1'])**2)**1.5) \
                        / np.absolute(2*real_space_pred_rightLane['a2'])
    
    middle_radius = (left_radius + right_radius)/2
    cv2.putText(result, 'Radius of curvature='+ str(round(middle_radius)) +'(m)', (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255))
    
    if showMe:
        plt.title('Final Result')
        plt.imshow(result)
        plt.show()
    
    return result.astype('uint8')


def run_pipeline(input_image):
    k_blur = 5
    bottom_crop = -60 #front-end car
    sliding_window_specs = {'width': 80, 'n_steps': 9} #number of steps vertical steps of sliding window
    hot_pixel_thresh = 100 # if number of hot pixel in window below 50, #consider them as noise and do not attempt to get centroid
    
    img_sz = (input_image.shape[1], input_image.shape[0])
    ym_per_pix = 30/720 # meters per pixel in y dimension
    xm_per_pix = 3.7/700 # meters per pixel in x dimension
    #birdview_pts = {'src_pts': src_pts, 'dst_pts': dst_pts}
    #input_image = cv2.imread('test_images/straight_lines1.jpg')
    ref_point_radius = input_image.shape[0]

    draw_lane_thickness = 20 #hwo thick to draw predicted lanes in px
    input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)


    draw_lane_thickness = 20 #hwo thick to draw predicted lanes in px
    input_image = cv2.cvtColor(input_image, cv2.COLOR_BGR2RGB)
    result = pipeline_predict_lanes(input_image, showMe=1)
    return result

# %%
white_output = 'project_solution.mp4'
clip1 = VideoFileClip("project_video.mp4")
white_clip = clip1.fl_image(pipeline_predict_lanes) #NOTE: this function expects color images!!
# %time white_clip.write_videofile(white_output, audio=False)
# Out:
# *************************** 388.518581976
# [MoviePy] >>>> Building video project_solution.mp4
# [MoviePy] Writing video project_solution.mp4
#   0%|          | 1/1261 [00:00<08:16,  2.54it/s]
# *************************** 388.518581976
#   0%|          | 2/1261 [00:00<08:13,  2.55it/s]
# *************************** 388.312597419
#   0%|          | 3/1261 [00:01<08:17,  2.53it/s]
# *************************** 387.538083166
#   0%|          | 4/1261 [00:01<08:25,  2.49it/s]
# *************************** 387.021972254
#   0%|          | 5/1261 [00:02<08:37,  2.43it/s]
# *************************** 388.083046891
#   0%|          | 6/1261 [00:02<08:23,  2.49it/s]
# *************************** 391.999921423
#   1%|          | 7/1261 [00:02<08:16,  2.53it/s]
# *************************** 392.69128815
#   1%|          | 8/1261 [00:03<08:17,  2.52it/s]
# *************************** 392.81217479
#   1%|          | 9/1261 [00:03<08:36,  2.42it/s]
# *************************** 393.132665176
#   1%|          | 10/1261 [00:04<08:17,  2.52it/s]
# *************************** 392.707390828
#   1%|          | 11/1261 [00:04<07:56,  2.62it/s]
# *************************** 393.401301004
#   1%|          | 12/1261 [00:04<07:45,  2.69it/s]
# *************************** 393.313369513
#   1%|          | 13/1261 [00:05<07:43,  2.69it/s]
# *************************** 395.011163828
#   1%|          | 14/1261 [00:05<07:37,  2.73it/s]
# *************************** 394.706290018
#   1%|          | 15/1261 [00:05<08:00,  2.59it/s]
# *************************** 395.015284344
#   1%|▏         | 16/1261 [00:06<08:30,  2.44it/s]
# *************************** 394.999850692
#   1%|▏         | 17/1261 [00:06<08:25,  2.46it/s]
# *************************** 391.610582849
#   1%|▏         | 18/1261 [00:07<08:01,  2.58it/s]
# *************************** 394.267620778
#   2%|▏         | 19/1261 [00:07<08:04,  2.57it/s]
# *************************** 391.543405421
#   2%|▏         | 20/1261 [00:07<07:48,  2.65it/s]
# *************************** 391.681300415
#   2%|▏         | 21/1261 [00:08<07:43,  2.68it/s]
# *************************** 391.873484234
#   2%|▏         | 22/1261 [00:08<08:00,  2.58it/s]
# *************************** 391.315768922
#   2%|▏         | 23/1261 [00:08<07:57,  2.59it/s]
# *************************** 388.484468741
#   2%|▏         | 24/1261 [00:09<08:11,  2.52it/s]
# *************************** 386.959597554
#   2%|▏         | 25/1261 [00:09<07:54,  2.60it/s]
# *************************** 387.348823486
#   2%|▏         | 26/1261 [00:10<07:55,  2.60it/s]
# *************************** 386.671956545
#   2%|▏         | 27/1261 [00:10<08:05,  2.54it/s]
# *************************** 385.726758964
#   2%|▏         | 28/1261 [00:10<07:59,  2.57it/s]
# *************************** 383.091649183
#   2%|▏         | 29/1261 [00:11<07:44,  2.65it/s]
# *************************** 380.436739838
#   2%|▏         | 30/1261 [00:11<07:30,  2.73it/s]
# *************************** 378.773832517
#   2%|▏         | 31/1261 [00:11<07:31,  2.73it/s]
# *************************** 375.966238164
#   3%|▎         | 32/1261 [00:12<07:25,  2.76it/s]
# *************************** 377.292712465
#   3%|▎         | 33/1261 [00:12<07:28,  2.74it/s]
# *************************** 375.21814508
#   3%|▎         | 34/1261 [00:13<07:51,  2.60it/s]
# *************************** 375.764095126
#   3%|▎         | 35/1261 [00:13<07:50,  2.61it/s]
# *************************** 377.947569504
#   3%|▎         | 36/1261 [00:13<07:51,  2.60it/s]
# *************************** 379.289434201
#   3%|▎         | 37/1261 [00:14<07:47,  2.62it/s]
# *************************** 381.151102857
#   3%|▎         | 38/1261 [00:14<07:44,  2.63it/s]
# *************************** 383.014095992
#   3%|▎         | 39/1261 [00:15<08:17,  2.46it/s]
# *************************** 383.170796573
#   3%|▎         | 40/1261 [00:15<07:57,  2.56it/s]
# *************************** 384.253623012
#   3%|▎         | 41/1261 [00:15<07:48,  2.60it/s]
# *************************** 384.787311059
#   3%|▎         | 42/1261 [00:16<07:44,  2.63it/s]
# *************************** 384.483709368
#   3%|▎         | 43/1261 [00:16<07:45,  2.62it/s]
# *************************** 386.556974788
#   3%|▎         | 44/1261 [00:16<07:40,  2.64it/s]
# *************************** 386.738121008
#   4%|▎         | 45/1261 [00:17<07:29,  2.71it/s]
# *************************** 384.845141756
#   4%|▎         | 46/1261 [00:17<07:23,  2.74it/s]
# *************************** 383.150263307
#   4%|▎         | 47/1261 [00:18<07:26,  2.72it/s]
# *************************** 382.64755384
#   4%|▍         | 48/1261 [00:18<07:26,  2.71it/s]
# *************************** 383.271402768
#   4%|▍         | 49/1261 [00:18<07:29,  2.70it/s]
# *************************** 383.651304561
#   4%|▍         | 50/1261 [00:19<07:24,  2.73it/s]
# *************************** 385.19039895
#   4%|▍         | 51/1261 [00:19<07:21,  2.74it/s]
# *************************** 387.182566455
#   4%|▍         | 52/1261 [00:19<07:21,  2.74it/s]
# *************************** 388.630976492
#   4%|▍         | 53/1261 [00:20<07:25,  2.71it/s]
# *************************** 389.165068927
#   4%|▍         | 54/1261 [00:20<07:45,  2.60it/s]
# *************************** 387.422890297
#   4%|▍         | 55/1261 [00:21<07:35,  2.65it/s]
# *************************** 384.326901864
#   4%|▍         | 56/1261 [00:21<07:50,  2.56it/s]
# *************************** 385.107375437
#   5%|▍         | 57/1261 [00:21<07:43,  2.60it/s]
# *************************** 387.262884507
#   5%|▍         | 58/1261 [00:22<07:33,  2.65it/s]
# *************************** 385.330834376
#   5%|▍         | 59/1261 [00:22<07:26,  2.69it/s]
# *************************** 385.821755352
#   5%|▍         | 60/1261 [00:22<07:23,  2.71it/s]
# *************************** 386.880141095
#   5%|▍         | 61/1261 [00:23<07:23,  2.70it/s]
# *************************** 385.995333747
#   5%|▍         | 62/1261 [00:23<07:18,  2.73it/s]
# *************************** 386.691046347
#   5%|▍         | 63/1261 [00:24<07:44,  2.58it/s]
# *************************** 385.89249732
#   5%|▌         | 64/1261 [00:24<07:37,  2.62it/s]
# *************************** 385.416665101
#   5%|▌         | 65/1261 [00:24<07:39,  2.60it/s]
# *************************** 383.483060174
#   5%|▌         | 66/1261 [00:25<07:32,  2.64it/s]
# *************************** 382.710191944
#   5%|▌         | 67/1261 [00:25<07:28,  2.66it/s]
# *************************** 379.233269075
#   5%|▌         | 68/1261 [00:25<07:32,  2.64it/s]
# *************************** 376.288470927
#   5%|▌         | 69/1261 [00:26<07:57,  2.50it/s]
# *************************** 375.65264416
#   6%|▌         | 70/1261 [00:26<07:44,  2.56it/s]
# *************************** 371.321149878
#   6%|▌         | 71/1261 [00:27<07:32,  2.63it/s]
# *************************** 370.610567904
#   6%|▌         | 72/1261 [00:27<07:23,  2.68it/s]
# *************************** 368.140698771
#   6%|▌         | 73/1261 [00:27<07:27,  2.66it/s]
# *************************** 366.931963713
#   6%|▌         | 74/1261 [00:28<07:25,  2.67it/s]
# *************************** 367.075018909
#   6%|▌         | 75/1261 [00:28<07:22,  2.68it/s]
# *************************** 367.513616382
#   6%|▌         | 76/1261 [00:28<07:15,  2.72it/s]
# *************************** 368.565238415
#   6%|▌         | 77/1261 [00:29<07:19,  2.69it/s]
# *************************** 369.222995416
#   6%|▌         | 78/1261 [00:29<07:18,  2.70it/s]
# *************************** 370.151835619
#   6%|▋         | 79/1261 [00:30<07:23,  2.67it/s]
# *************************** 369.983620054
#   6%|▋         | 80/1261 [00:30<07:18,  2.69it/s]
# *************************** 367.819645674
#   6%|▋         | 81/1261 [00:30<07:20,  2.68it/s]
# *************************** 366.849090599
#   7%|▋         | 82/1261 [00:31<07:19,  2.69it/s]
# *************************** 365.665820758
#   7%|▋         | 83/1261 [00:31<07:12,  2.72it/s]
# *************************** 364.3278659
#   7%|▋         | 84/1261 [00:31<07:09,  2.74it/s]
# *************************** 361.118980853
#   7%|▋         | 85/1261 [00:32<07:21,  2.66it/s]
# *************************** 359.026578171
#   7%|▋         | 86/1261 [00:32<07:19,  2.67it/s]
# *************************** 356.0619865
#   7%|▋         | 87/1261 [00:33<07:20,  2.66it/s]
# *************************** 356.185836347
#   7%|▋         | 88/1261 [00:33<07:14,  2.70it/s]
# *************************** 356.485106545
#   7%|▋         | 89/1261 [00:33<07:17,  2.68it/s]
# *************************** 358.031178534
#   7%|▋         | 90/1261 [00:34<07:18,  2.67it/s]
# *************************** 358.898217701
#   7%|▋         | 91/1261 [00:34<07:34,  2.57it/s]
# *************************** 359.037671372
#   7%|▋         | 92/1261 [00:35<07:32,  2.58it/s]
# *************************** 358.932428004
#   7%|▋         | 93/1261 [00:35<09:07,  2.13it/s]
# *************************** 359.421404238
#   7%|▋         | 94/1261 [00:36<09:27,  2.06it/s]
# *************************** 360.961474951
#   8%|▊         | 95/1261 [00:36<09:34,  2.03it/s]
# *************************** 359.537809912
#   8%|▊         | 96/1261 [00:37<09:42,  2.00it/s]
# *************************** 358.731771473
#   8%|▊         | 97/1261 [00:37<09:06,  2.13it/s]
# *************************** 359.586350128
#   8%|▊         | 98/1261 [00:38<08:44,  2.22it/s]
# *************************** 359.835527712
#   8%|▊         | 99/1261 [00:38<08:16,  2.34it/s]
# *************************** 361.817359193
#   8%|▊         | 100/1261 [00:38<07:59,  2.42it/s]
# *************************** 361.763639398
#   8%|▊         | 101/1261 [00:39<07:46,  2.49it/s]
# *************************** 364.679187418
#   8%|▊         | 102/1261 [00:39<07:30,  2.57it/s]
# *************************** 366.66573124
#   8%|▊         | 103/1261 [00:39<07:25,  2.60it/s]
# *************************** 367.993111117
#   8%|▊         | 104/1261 [00:40<07:37,  2.53it/s]
# *************************** 370.629161435
#   8%|▊         | 105/1261 [00:40<07:31,  2.56it/s]
# *************************** 368.13387542
#   8%|▊         | 106/1261 [00:41<07:21,  2.62it/s]
# *************************** 369.018865681
#   8%|▊         | 107/1261 [00:41<07:10,  2.68it/s]
# *************************** 370.187197203
#   9%|▊         | 108/1261 [00:41<07:28,  2.57it/s]
# *************************** 370.406660824
#   9%|▊         | 109/1261 [00:42<07:22,  2.60it/s]
# *************************** 369.95783635
#   9%|▊         | 110/1261 [00:42<07:20,  2.61it/s]
# *************************** 370.322494757
#   9%|▉         | 111/1261 [00:42<07:14,  2.65it/s]
# *************************** 371.872438447
#   9%|▉         | 112/1261 [00:43<07:15,  2.64it/s]
# *************************** 370.844740701
#   9%|▉         | 113/1261 [00:43<07:14,  2.64it/s]
# *************************** 370.973477945
#   9%|▉         | 114/1261 [00:44<07:17,  2.62it/s]
# *************************** 372.467194145
#   9%|▉         | 115/1261 [00:44<07:15,  2.63it/s]
# *************************** 374.38766907
#   9%|▉         | 116/1261 [00:44<07:09,  2.66it/s]
# *************************** 375.743871153
#   9%|▉         | 117/1261 [00:45<07:08,  2.67it/s]
# *************************** 374.522073056
#   9%|▉         | 118/1261 [00:45<07:12,  2.64it/s]
# *************************** 375.571630975
#   9%|▉         | 119/1261 [00:45<07:09,  2.66it/s]
# *************************** 376.949759295
#  10%|▉         | 120/1261 [00:46<07:16,  2.61it/s]
# *************************** 378.821286517
#  10%|▉         | 121/1261 [00:46<07:39,  2.48it/s]
# *************************** 378.21151174
#  10%|▉         | 122/1261 [00:47<07:49,  2.42it/s]
# *************************** 378.606767078
#  10%|▉         | 123/1261 [00:47<07:45,  2.45it/s]
# *************************** 380.341885342
#  10%|▉         | 124/1261 [00:48<07:58,  2.38it/s]
# *************************** 381.535207273
#  10%|▉         | 125/1261 [00:48<09:53,  1.91it/s]
# *************************** 383.924001237
#  10%|▉         | 126/1261 [00:49<09:10,  2.06it/s]
# *************************** 385.385881721
#  10%|█         | 127/1261 [00:49<09:16,  2.04it/s]
# *************************** 386.020274839
#  10%|█         | 128/1261 [00:50<08:46,  2.15it/s]
# *************************** 387.5903632
#  10%|█         | 129/1261 [00:50<08:20,  2.26it/s]
# *************************** 388.99452755
#  10%|█         | 130/1261 [00:50<08:02,  2.34it/s]
# *************************** 386.160568403
#  10%|█         | 131/1261 [00:51<07:51,  2.40it/s]
# *************************** 386.806370448
#  10%|█         | 132/1261 [00:51<07:38,  2.46it/s]
# *************************** 388.246494257
#  11%|█         | 133/1261 [00:52<08:04,  2.33it/s]
# *************************** 390.257710498
#  11%|█         | 134/1261 [00:52<08:15,  2.27it/s]
# *************************** 391.990501874
#  11%|█         | 135/1261 [00:53<08:20,  2.25it/s]
# *************************** 393.097201077
#  11%|█         | 136/1261 [00:53<07:55,  2.37it/s]
# *************************** 393.668070923
#  11%|█         | 137/1261 [00:53<07:51,  2.38it/s]
# *************************** 393.020114381
#  11%|█         | 138/1261 [00:54<07:54,  2.37it/s]
# *************************** 391.820442464
#  11%|█         | 139/1261 [00:54<07:35,  2.46it/s]
# *************************** 392.978115603
#  11%|█         | 140/1261 [00:55<07:20,  2.54it/s]
# *************************** 392.840756828
#  11%|█         | 141/1261 [00:55<07:14,  2.58it/s]
# *************************** 393.932386901
#  11%|█▏        | 142/1261 [00:55<07:05,  2.63it/s]
# *************************** 390.653706843
#  11%|█▏        | 143/1261 [00:56<06:57,  2.68it/s]
# *************************** 389.862684031
#  11%|█▏        | 144/1261 [00:56<06:51,  2.71it/s]
# *************************** 389.618547748
#  11%|█▏        | 145/1261 [00:56<06:51,  2.71it/s]
# *************************** 386.982529454
#  12%|█▏        | 146/1261 [00:57<06:47,  2.74it/s]
# *************************** 384.855307081
#  12%|█▏        | 147/1261 [00:57<06:45,  2.75it/s]
# *************************** 384.493452932
#  12%|█▏        | 148/1261 [00:58<06:54,  2.69it/s]
# *************************** 386.810532057
#  12%|█▏        | 149/1261 [00:58<06:55,  2.68it/s]
# *************************** 387.706913788
#  12%|█▏        | 150/1261 [00:58<06:59,  2.65it/s]
# *************************** 387.793930128
#  12%|█▏        | 151/1261 [00:59<06:52,  2.69it/s]
# *************************** 387.574497447
#  12%|█▏        | 152/1261 [00:59<06:52,  2.69it/s]
# *************************** 387.16847424
#  12%|█▏        | 153/1261 [00:59<06:57,  2.65it/s]
# *************************** 388.490876016
#  12%|█▏        | 154/1261 [01:00<06:57,  2.65it/s]
# *************************** 386.397724392
#  12%|█▏        | 155/1261 [01:00<06:57,  2.65it/s]
# *************************** 386.742351276
#  12%|█▏        | 156/1261 [01:01<06:51,  2.69it/s]
# *************************** 387.725290153
#  12%|█▏        | 157/1261 [01:01<07:01,  2.62it/s]
# *************************** 386.728950583
#  13%|█▎        | 158/1261 [01:01<06:56,  2.65it/s]
# *************************** 384.096114167
#  13%|█▎        | 159/1261 [01:02<06:54,  2.66it/s]
# *************************** 381.337893017
#  13%|█▎        | 160/1261 [01:02<07:06,  2.58it/s]
# *************************** 379.151874265
#  13%|█▎        | 161/1261 [01:02<07:04,  2.59it/s]
# *************************** 376.336427179
#  13%|█▎        | 162/1261 [01:03<07:08,  2.57it/s]
# *************************** 374.804160496
#  13%|█▎        | 163/1261 [01:03<07:10,  2.55it/s]
# *************************** 374.129094909
#  13%|█▎        | 164/1261 [01:04<07:05,  2.58it/s]
# *************************** 375.691083413
#  13%|█▎        | 165/1261 [01:04<07:00,  2.61it/s]
# *************************** 377.200122582
#  13%|█▎        | 166/1261 [01:04<06:52,  2.65it/s]
# *************************** 377.336192528
#  13%|█▎        | 167/1261 [01:05<06:48,  2.68it/s]
# *************************** 375.314178399
#  13%|█▎        | 168/1261 [01:05<06:45,  2.70it/s]
# *************************** 374.969191566
#  13%|█▎        | 169/1261 [01:05<06:55,  2.63it/s]
# *************************** 374.92185849
#  13%|█▎        | 170/1261 [01:06<06:51,  2.65it/s]
# *************************** 371.716168972
#  14%|█▎        | 171/1261 [01:06<06:49,  2.66it/s]
# *************************** 371.273747154
#  14%|█▎        | 172/1261 [01:07<06:44,  2.69it/s]
# *************************** 369.809608566
#  14%|█▎        | 173/1261 [01:07<06:43,  2.70it/s]
# *************************** 369.562201795
#  14%|█▍        | 174/1261 [01:07<06:46,  2.67it/s]
# *************************** 370.226134864
#  14%|█▍        | 175/1261 [01:08<07:09,  2.53it/s]
# *************************** 369.806648426
#  14%|█▍        | 176/1261 [01:08<07:02,  2.57it/s]
# *************************** 368.969033216
#  14%|█▍        | 177/1261 [01:09<06:57,  2.60it/s]
# *************************** 368.146986053
#  14%|█▍        | 178/1261 [01:09<06:51,  2.63it/s]
# *************************** 369.456302223
#  14%|█▍        | 179/1261 [01:09<06:44,  2.67it/s]
# *************************** 369.06941572
#  14%|█▍        | 180/1261 [01:10<06:37,  2.72it/s]
# *************************** 368.633109286
#  14%|█▍        | 181/1261 [01:10<06:38,  2.71it/s]
# *************************** 369.933412978
#  14%|█▍        | 182/1261 [01:10<06:37,  2.71it/s]
# *************************** 369.239185262
#  15%|█▍        | 183/1261 [01:11<06:33,  2.74it/s]
# *************************** 368.150919142
#  15%|█▍        | 184/1261 [01:11<06:28,  2.77it/s]
# *************************** 367.555914932
#  15%|█▍        | 185/1261 [01:11<06:32,  2.74it/s]
# *************************** 366.280488518
#  15%|█▍        | 186/1261 [01:12<06:28,  2.77it/s]
# *************************** 364.394840027
#  15%|█▍        | 187/1261 [01:12<06:30,  2.75it/s]
# *************************** 362.860968761
#  15%|█▍        | 188/1261 [01:13<06:28,  2.76it/s]
# *************************** 362.661001525
#  15%|█▍        | 189/1261 [01:13<06:36,  2.71it/s]
# *************************** 364.084538224
#  15%|█▌        | 190/1261 [01:13<06:41,  2.67it/s]
# *************************** 368.088940683
#  15%|█▌        | 191/1261 [01:14<06:43,  2.65it/s]
# *************************** 370.017270834
#  15%|█▌        | 192/1261 [01:14<06:38,  2.68it/s]
# *************************** 374.666328776
#  15%|█▌        | 193/1261 [01:14<06:44,  2.64it/s]
# *************************** 377.594902959
#  15%|█▌        | 194/1261 [01:15<06:41,  2.66it/s]
# *************************** 379.037073486
#  15%|█▌        | 195/1261 [01:15<06:36,  2.69it/s]
# *************************** 379.479384232
#  16%|█▌        | 196/1261 [01:16<06:35,  2.69it/s]
# *************************** 377.674751849
#  16%|█▌        | 197/1261 [01:16<06:42,  2.64it/s]
# *************************** 376.873005925
#  16%|█▌        | 198/1261 [01:16<06:49,  2.60it/s]
# *************************** 373.717859513
#  16%|█▌        | 199/1261 [01:17<06:47,  2.61it/s]
# *************************** 372.256314468
#  16%|█▌        | 200/1261 [01:17<06:59,  2.53it/s]
# *************************** 371.941580097
#  16%|█▌        | 201/1261 [01:18<07:04,  2.50it/s]
# *************************** 370.540783298
#  16%|█▌        | 202/1261 [01:18<06:54,  2.56it/s]
# *************************** 369.154114279
#  16%|█▌        | 203/1261 [01:18<06:46,  2.60it/s]
# *************************** 367.208075078
#  16%|█▌        | 204/1261 [01:19<06:38,  2.65it/s]
# *************************** 364.362242753
#  16%|█▋        | 205/1261 [01:19<06:38,  2.65it/s]
# *************************** 365.424183545
#  16%|█▋        | 206/1261 [01:19<06:37,  2.65it/s]
# *************************** 367.29412577
#  16%|█▋        | 207/1261 [01:20<06:40,  2.63it/s]
# *************************** 368.416603093
#  16%|█▋        | 208/1261 [01:20<06:39,  2.64it/s]
# *************************** 370.023411395
#  17%|█▋        | 209/1261 [01:21<06:38,  2.64it/s]
# *************************** 370.897391598
#  17%|█▋        | 210/1261 [01:21<06:35,  2.66it/s]
# *************************** 370.84020698
#  17%|█▋        | 211/1261 [01:21<06:32,  2.68it/s]
# *************************** 371.362698768
#  17%|█▋        | 212/1261 [01:22<06:46,  2.58it/s]
# *************************** 371.850026723
#  17%|█▋        | 213/1261 [01:22<06:45,  2.58it/s]
# *************************** 371.799467249
#  17%|█▋        | 214/1261 [01:22<06:38,  2.63it/s]
# *************************** 370.28274409
#  17%|█▋        | 215/1261 [01:23<06:37,  2.63it/s]
# *************************** 368.65419075
#  17%|█▋        | 216/1261 [01:23<06:47,  2.57it/s]
# *************************** 363.859319115
#  17%|█▋        | 217/1261 [01:24<06:52,  2.53it/s]
# *************************** 363.040373464
#  17%|█▋        | 218/1261 [01:24<06:56,  2.50it/s]
# *************************** 361.962630665
#  17%|█▋        | 219/1261 [01:24<06:45,  2.57it/s]
# *************************** 362.629321494
#  17%|█▋        | 220/1261 [01:25<06:42,  2.59it/s]
# *************************** 361.708327735
#  18%|█▊        | 221/1261 [01:25<06:42,  2.58it/s]
# *************************** 364.156814783
#  18%|█▊        | 222/1261 [01:26<06:43,  2.58it/s]
# *************************** 365.804290527
#  18%|█▊        | 223/1261 [01:26<06:47,  2.54it/s]
# *************************** 366.528781823
#  18%|█▊        | 224/1261 [01:26<06:45,  2.56it/s]
# *************************** 367.614707781
#  18%|█▊        | 225/1261 [01:27<06:39,  2.59it/s]
# *************************** 366.760111769
#  18%|█▊        | 226/1261 [01:27<06:34,  2.62it/s]
# *************************** 366.774483877
#  18%|█▊        | 227/1261 [01:27<06:32,  2.63it/s]
# *************************** 365.043151208
#  18%|█▊        | 228/1261 [01:28<06:36,  2.61it/s]
# *************************** 361.519276127
#  18%|█▊        | 229/1261 [01:28<06:37,  2.60it/s]
# *************************** 360.376384282
#  18%|█▊        | 230/1261 [01:29<06:43,  2.55it/s]
# *************************** 361.587312895
#  18%|█▊        | 231/1261 [01:29<06:50,  2.51it/s]
# *************************** 361.043237785
#  18%|█▊        | 232/1261 [01:30<06:57,  2.46it/s]
# *************************** 359.579375783
#  18%|█▊        | 233/1261 [01:30<07:19,  2.34it/s]
# *************************** 358.154683726
#  19%|█▊        | 234/1261 [01:31<09:03,  1.89it/s]
# *************************** 356.137389928
#  19%|█▊        | 235/1261 [01:31<09:56,  1.72it/s]
# *************************** 354.16827249
#  19%|█▊        | 236/1261 [01:32<08:49,  1.94it/s]
# *************************** 352.861128156
#  19%|█▉        | 237/1261 [01:32<08:08,  2.09it/s]
# *************************** 352.019881283
#  19%|█▉        | 238/1261 [01:33<07:36,  2.24it/s]
# *************************** 352.66765071
#  19%|█▉        | 239/1261 [01:33<07:11,  2.37it/s]
# *************************** 351.408535022
#  19%|█▉        | 240/1261 [01:33<07:06,  2.39it/s]
# *************************** 350.168394505
#  19%|█▉        | 241/1261 [01:34<07:29,  2.27it/s]
# *************************** 349.268305277
#  19%|█▉        | 242/1261 [01:34<07:46,  2.18it/s]
# *************************** 348.337645658
#  19%|█▉        | 243/1261 [01:35<07:46,  2.18it/s]
# *************************** 346.654690472
#  19%|█▉        | 244/1261 [01:35<07:39,  2.21it/s]
# *************************** 344.543260866
#  19%|█▉        | 245/1261 [01:36<07:35,  2.23it/s]
# *************************** 343.989603303
#  20%|█▉        | 246/1261 [01:36<07:15,  2.33it/s]
# *************************** 343.606809928
#  20%|█▉        | 247/1261 [01:36<06:55,  2.44it/s]
# *************************** 341.923167618
#  20%|█▉        | 248/1261 [01:37<06:44,  2.51it/s]
# *************************** 342.530465211
#  20%|█▉        | 249/1261 [01:37<06:39,  2.54it/s]
# *************************** 341.155708663
#  20%|█▉        | 250/1261 [01:38<06:37,  2.54it/s]
# *************************** 341.937753629
#  20%|█▉        | 251/1261 [01:38<06:37,  2.54it/s]
# *************************** 342.847622321
#  20%|█▉        | 252/1261 [01:38<06:28,  2.60it/s]
# *************************** 341.564536391
#  20%|██        | 253/1261 [01:39<06:27,  2.60it/s]
# *************************** 342.222628367
#  20%|██        | 254/1261 [01:39<06:26,  2.61it/s]
# *************************** 343.080490729
#  20%|██        | 255/1261 [01:39<06:24,  2.62it/s]
# *************************** 343.894497882
#  20%|██        | 256/1261 [01:40<06:21,  2.64it/s]
# *************************** 342.187758586
#  20%|██        | 257/1261 [01:40<06:17,  2.66it/s]
# *************************** 340.911576038
#  20%|██        | 258/1261 [01:41<06:19,  2.64it/s]
# *************************** 340.31791675
#  21%|██        | 259/1261 [01:41<06:13,  2.68it/s]
# *************************** 340.221735678
#  21%|██        | 260/1261 [01:41<06:14,  2.67it/s]
# *************************** 342.907685738
#  21%|██        | 261/1261 [01:42<06:24,  2.60it/s]
# *************************** 344.684469291
#  21%|██        | 262/1261 [01:42<06:20,  2.62it/s]
# *************************** 347.983821938
#  21%|██        | 263/1261 [01:43<06:34,  2.53it/s]
# *************************** 349.614999748
#  21%|██        | 264/1261 [01:43<06:47,  2.45it/s]
# *************************** 347.805745635
#  21%|██        | 265/1261 [01:43<06:53,  2.41it/s]
# *************************** 346.78624695
#  21%|██        | 266/1261 [01:44<07:29,  2.21it/s]
# *************************** 345.417744019
#  21%|██        | 267/1261 [01:44<07:22,  2.25it/s]
# *************************** 343.22177508
#  21%|██▏       | 268/1261 [01:45<07:17,  2.27it/s]
# *************************** 340.501059013
#  21%|██▏       | 269/1261 [01:45<08:00,  2.06it/s]
# *************************** 339.397615379
#  21%|██▏       | 270/1261 [01:46<07:49,  2.11it/s]
# *************************** 339.287755031
#  21%|██▏       | 271/1261 [01:46<07:46,  2.12it/s]
# *************************** 340.198951395
#  22%|██▏       | 272/1261 [01:47<07:45,  2.13it/s]
# *************************** 342.187227461
#  22%|██▏       | 273/1261 [01:47<07:52,  2.09it/s]
# *************************** 344.560499636
#  22%|██▏       | 274/1261 [01:48<08:44,  1.88it/s]
# *************************** 347.908735217
#  22%|██▏       | 275/1261 [01:48<08:05,  2.03it/s]
# *************************** 350.526836795
#  22%|██▏       | 276/1261 [01:49<07:35,  2.16it/s]
# *************************** 348.442224109
#  22%|██▏       | 277/1261 [01:49<07:29,  2.19it/s]
# *************************** 348.894175347
#  22%|██▏       | 278/1261 [01:50<07:41,  2.13it/s]
# *************************** 349.291360051
#  22%|██▏       | 279/1261 [01:50<08:14,  1.99it/s]
# *************************** 350.18034297
#  22%|██▏       | 280/1261 [01:51<08:36,  1.90it/s]
# *************************** 350.301932231
#  22%|██▏       | 281/1261 [01:52<10:25,  1.57it/s]
# *************************** 350.873664794
#  22%|██▏       | 282/1261 [01:53<12:12,  1.34it/s]
# *************************** 353.489807873
#  22%|██▏       | 283/1261 [01:54<13:18,  1.22it/s]
# *************************** 354.724649559
#  23%|██▎       | 284/1261 [01:55<13:36,  1.20it/s]
# *************************** 356.570917816
#  23%|██▎       | 285/1261 [01:55<12:15,  1.33it/s]
# *************************** 358.409057315
#  23%|██▎       | 286/1261 [01:56<10:22,  1.57it/s]
# *************************** 358.702905059
#  23%|██▎       | 287/1261 [01:56<09:08,  1.78it/s]
# *************************** 359.537376595
#  23%|██▎       | 288/1261 [01:56<08:37,  1.88it/s]
# *************************** 359.635555996
#  23%|██▎       | 289/1261 [01:57<09:07,  1.77it/s]
# *************************** 360.580932148
#  23%|██▎       | 290/1261 [01:57<08:30,  1.90it/s]
# *************************** 360.206679721
#  23%|██▎       | 291/1261 [01:58<08:01,  2.01it/s]
# *************************** 362.348776092
#  23%|██▎       | 292/1261 [01:58<08:02,  2.01it/s]
# *************************** 363.316917809
#  23%|██▎       | 293/1261 [01:59<07:49,  2.06it/s]
# *************************** 363.351802138
#  23%|██▎       | 294/1261 [01:59<07:24,  2.17it/s]
# *************************** 364.522239927
#  23%|██▎       | 295/1261 [02:00<08:33,  1.88it/s]
# *************************** 364.98772703
#  23%|██▎       | 296/1261 [02:00<08:09,  1.97it/s]
# *************************** 366.758168122
#  24%|██▎       | 297/1261 [02:01<07:28,  2.15it/s]
# *************************** 367.55455339
#  24%|██▎       | 298/1261 [02:01<07:43,  2.08it/s]
# *************************** 368.686899078
#  24%|██▎       | 299/1261 [02:02<07:51,  2.04it/s]
# *************************** 369.385942368
#  24%|██▍       | 300/1261 [02:02<07:15,  2.21it/s]
# *************************** 368.407396518
#  24%|██▍       | 301/1261 [02:03<06:54,  2.32it/s]
# *************************** 366.79215764
#  24%|██▍       | 302/1261 [02:03<06:36,  2.42it/s]
# *************************** 365.879901158
#  24%|██▍       | 303/1261 [02:03<06:22,  2.50it/s]
# *************************** 365.496316084
#  24%|██▍       | 304/1261 [02:04<06:21,  2.51it/s]
# *************************** 364.401158741
#  24%|██▍       | 305/1261 [02:04<06:10,  2.58it/s]
# *************************** 363.15001359
#  24%|██▍       | 306/1261 [02:04<06:06,  2.61it/s]
# *************************** 364.17635954
#  24%|██▍       | 307/1261 [02:05<06:02,  2.63it/s]
# *************************** 363.796365673
#  24%|██▍       | 308/1261 [02:05<05:55,  2.68it/s]
# *************************** 365.958628877
#  25%|██▍       | 309/1261 [02:05<05:48,  2.73it/s]
# *************************** 366.959760091
#  25%|██▍       | 310/1261 [02:06<05:48,  2.73it/s]
# *************************** 368.637175978
#  25%|██▍       | 311/1261 [02:06<05:46,  2.74it/s]
# *************************** 371.513891103
#  25%|██▍       | 312/1261 [02:07<05:47,  2.73it/s]
# *************************** 373.323072231
#  25%|██▍       | 313/1261 [02:07<05:48,  2.72it/s]
# *************************** 373.40394738
#  25%|██▍       | 314/1261 [02:07<05:49,  2.71it/s]
# *************************** 373.821318852
#  25%|██▍       | 315/1261 [02:08<05:57,  2.64it/s]
# *************************** 373.640326306
#  25%|██▌       | 316/1261 [02:08<05:53,  2.67it/s]
# *************************** 372.375067308
#  25%|██▌       | 317/1261 [02:08<05:55,  2.65it/s]
# *************************** 371.551554258
#  25%|██▌       | 318/1261 [02:09<05:51,  2.68it/s]
# *************************** 371.534353413
#  25%|██▌       | 319/1261 [02:09<05:49,  2.69it/s]
# *************************** 371.324681368
#  25%|██▌       | 320/1261 [02:10<05:49,  2.69it/s]
# *************************** 372.151733586
#  25%|██▌       | 321/1261 [02:10<05:47,  2.70it/s]
# *************************** 373.037969442
#  26%|██▌       | 322/1261 [02:10<05:53,  2.66it/s]
# *************************** 374.491530351
#  26%|██▌       | 323/1261 [02:11<05:48,  2.69it/s]
# *************************** 377.204430424
#  26%|██▌       | 324/1261 [02:11<05:46,  2.70it/s]
# *************************** 376.652645937
#  26%|██▌       | 325/1261 [02:11<05:40,  2.75it/s]
# *************************** 375.101807641
#  26%|██▌       | 326/1261 [02:12<05:46,  2.70it/s]
# *************************** 374.200493808
#  26%|██▌       | 327/1261 [02:12<05:48,  2.68it/s]
# *************************** 373.106716091
#  26%|██▌       | 328/1261 [02:13<05:43,  2.72it/s]
# *************************** 372.948263456
#  26%|██▌       | 329/1261 [02:13<05:45,  2.70it/s]
# *************************** 371.425270391
#  26%|██▌       | 330/1261 [02:13<05:44,  2.70it/s]
# *************************** 372.245766446
#  26%|██▌       | 331/1261 [02:14<05:45,  2.69it/s]
# *************************** 371.489908259
#  26%|██▋       | 332/1261 [02:14<05:40,  2.73it/s]
# *************************** 372.468823614
#  26%|██▋       | 333/1261 [02:14<05:34,  2.78it/s]
# *************************** 372.656873882
#  26%|██▋       | 334/1261 [02:15<05:35,  2.76it/s]
# *************************** 374.130042193
#  27%|██▋       | 335/1261 [02:15<05:34,  2.77it/s]
# *************************** 375.327792913
#  27%|██▋       | 336/1261 [02:15<05:42,  2.70it/s]
# *************************** 375.593644655
#  27%|██▋       | 337/1261 [02:16<05:40,  2.71it/s]
# *************************** 374.115014809
#  27%|██▋       | 338/1261 [02:16<05:39,  2.72it/s]
# *************************** 374.106708685
#  27%|██▋       | 339/1261 [02:17<05:34,  2.76it/s]
# *************************** 373.192566906
#  27%|██▋       | 340/1261 [02:17<05:30,  2.78it/s]
# *************************** 372.767152938
#  27%|██▋       | 341/1261 [02:17<05:27,  2.81it/s]
# *************************** 371.394254064
#  27%|██▋       | 342/1261 [02:18<05:40,  2.70it/s]
# *************************** 373.430532691
#  27%|██▋       | 343/1261 [02:18<05:36,  2.73it/s]
# *************************** 372.938358099
#  27%|██▋       | 344/1261 [02:18<05:32,  2.76it/s]
# *************************** 373.259034324
#  27%|██▋       | 345/1261 [02:19<05:28,  2.78it/s]
# *************************** 374.311906364
#  27%|██▋       | 346/1261 [02:19<05:31,  2.76it/s]
# *************************** 374.617137607
#  28%|██▊       | 347/1261 [02:19<05:29,  2.77it/s]
# *************************** 376.832667314
#  28%|██▊       | 348/1261 [02:20<05:27,  2.79it/s]
# *************************** 377.124499351
#  28%|██▊       | 349/1261 [02:20<05:26,  2.79it/s]
# *************************** 377.439271278
#  28%|██▊       | 350/1261 [02:21<05:27,  2.78it/s]
# *************************** 377.218314575
#  28%|██▊       | 351/1261 [02:21<05:27,  2.78it/s]
# *************************** 377.201896403
#  28%|██▊       | 352/1261 [02:21<05:24,  2.80it/s]
# *************************** 376.653120482
#  28%|██▊       | 353/1261 [02:22<05:29,  2.76it/s]
# *************************** 374.803396569
#  28%|██▊       | 354/1261 [02:22<05:31,  2.74it/s]
# *************************** 372.920595896
#  28%|██▊       | 355/1261 [02:22<05:35,  2.70it/s]
# *************************** 370.690167933
#  28%|██▊       | 356/1261 [02:23<05:30,  2.74it/s]
# *************************** 370.337375986
#  28%|██▊       | 357/1261 [02:23<05:24,  2.79it/s]
# *************************** 372.381227979
#  28%|██▊       | 358/1261 [02:23<05:29,  2.74it/s]
# *************************** 373.600849865
#  28%|██▊       | 359/1261 [02:24<05:38,  2.66it/s]
# *************************** 374.642532844
#  29%|██▊       | 360/1261 [02:24<05:32,  2.71it/s]
# *************************** 374.734199502
#  29%|██▊       | 361/1261 [02:25<05:34,  2.69it/s]
# *************************** 373.808687876
#  29%|██▊       | 362/1261 [02:25<05:32,  2.70it/s]
# *************************** 374.681429939
#  29%|██▉       | 363/1261 [02:25<05:28,  2.73it/s]
# *************************** 375.825638597
#  29%|██▉       | 364/1261 [02:26<05:27,  2.74it/s]
# *************************** 377.618311768
#  29%|██▉       | 365/1261 [02:26<05:33,  2.69it/s]
# *************************** 378.537592391
#  29%|██▉       | 366/1261 [02:26<05:31,  2.70it/s]
# *************************** 379.616633989
#  29%|██▉       | 367/1261 [02:27<05:44,  2.60it/s]
# *************************** 380.151699968
#  29%|██▉       | 368/1261 [02:27<05:42,  2.61it/s]
# *************************** 380.831156403
#  29%|██▉       | 369/1261 [02:28<05:56,  2.51it/s]
# *************************** 381.687534375
#  29%|██▉       | 370/1261 [02:28<05:48,  2.56it/s]
# *************************** 380.694742151
#  29%|██▉       | 371/1261 [02:28<05:47,  2.56it/s]
# *************************** 381.562580036
#  30%|██▉       | 372/1261 [02:29<06:31,  2.27it/s]
# *************************** 380.997043372
#  30%|██▉       | 373/1261 [02:29<06:30,  2.27it/s]
# *************************** 378.833884396
#  30%|██▉       | 374/1261 [02:30<06:42,  2.21it/s]
# *************************** 377.454507902
#  30%|██▉       | 375/1261 [02:30<06:33,  2.25it/s]
# *************************** 375.555830955
#  30%|██▉       | 376/1261 [02:31<06:19,  2.33it/s]
# *************************** 372.599877368
#  30%|██▉       | 377/1261 [02:31<06:09,  2.40it/s]
# *************************** 369.691017619
#  30%|██▉       | 378/1261 [02:32<06:12,  2.37it/s]
# *************************** 368.152051067
#  30%|███       | 379/1261 [02:32<07:06,  2.07it/s]
# *************************** 367.22634948
#  30%|███       | 380/1261 [02:33<07:19,  2.01it/s]
# *************************** 367.280088973
#  30%|███       | 381/1261 [02:33<07:04,  2.07it/s]
# *************************** 366.214381077
#  30%|███       | 382/1261 [02:34<06:42,  2.18it/s]
# *************************** 366.277597809
#  30%|███       | 383/1261 [02:34<06:25,  2.28it/s]
# *************************** 367.966384754
#  30%|███       | 384/1261 [02:34<06:14,  2.34it/s]
# *************************** 368.65204383
#  31%|███       | 385/1261 [02:35<06:02,  2.41it/s]
# *************************** 365.702384488
#  31%|███       | 386/1261 [02:35<06:02,  2.42it/s]
# *************************** 365.990219889
#  31%|███       | 387/1261 [02:36<05:56,  2.45it/s]
# *************************** 366.623082369
#  31%|███       | 388/1261 [02:36<05:58,  2.44it/s]
# *************************** 365.992946351
#  31%|███       | 389/1261 [02:36<05:59,  2.43it/s]
# *************************** 365.791128223
#  31%|███       | 390/1261 [02:37<06:04,  2.39it/s]
# *************************** 364.87408406
#  31%|███       | 391/1261 [02:37<05:53,  2.46it/s]
# *************************** 366.038331081
#  31%|███       | 392/1261 [02:38<05:45,  2.52it/s]
# *************************** 367.312478779
#  31%|███       | 393/1261 [02:38<05:47,  2.50it/s]
# *************************** 370.816744202
#  31%|███       | 394/1261 [02:38<05:45,  2.51it/s]
# *************************** 372.464306928
#  31%|███▏      | 395/1261 [02:39<05:46,  2.50it/s]
# *************************** 374.068868439
#  31%|███▏      | 396/1261 [02:39<05:38,  2.55it/s]
# *************************** 373.764132046
#  31%|███▏      | 397/1261 [02:39<05:35,  2.57it/s]
# *************************** 370.837090877
#  32%|███▏      | 398/1261 [02:40<05:33,  2.59it/s]
# *************************** 368.713404713
#  32%|███▏      | 399/1261 [02:40<05:44,  2.50it/s]
# *************************** 366.610668097
#  32%|███▏      | 400/1261 [02:41<05:34,  2.57it/s]
# *************************** 365.989888786
#  32%|███▏      | 401/1261 [02:41<05:35,  2.56it/s]
# *************************** 363.254294196
#  32%|███▏      | 402/1261 [02:41<05:44,  2.49it/s]
# *************************** 362.300041178
#  32%|███▏      | 403/1261 [02:42<05:37,  2.54it/s]
# *************************** 363.03833707
#  32%|███▏      | 404/1261 [02:42<05:31,  2.59it/s]
# *************************** 363.312045284
#  32%|███▏      | 405/1261 [02:43<05:24,  2.64it/s]
# *************************** 362.69648669
#  32%|███▏      | 406/1261 [02:43<05:24,  2.63it/s]
# *************************** 360.762445265
#  32%|███▏      | 407/1261 [02:43<05:24,  2.64it/s]
# *************************** 361.110674569
#  32%|███▏      | 408/1261 [02:44<05:34,  2.55it/s]
# *************************** 362.123890013
#  32%|███▏      | 409/1261 [02:44<05:28,  2.59it/s]
# *************************** 359.93852907
#  33%|███▎      | 410/1261 [02:45<05:31,  2.57it/s]
# *************************** 361.01293687
#  33%|███▎      | 411/1261 [02:45<05:24,  2.62it/s]
# *************************** 361.827809472
#  33%|███▎      | 412/1261 [02:45<05:19,  2.66it/s]
# *************************** 362.665529768
#  33%|███▎      | 413/1261 [02:46<05:29,  2.58it/s]
# *************************** 360.72013347
#  33%|███▎      | 414/1261 [02:46<05:27,  2.59it/s]
# *************************** 357.686145778
#  33%|███▎      | 415/1261 [02:46<05:23,  2.62it/s]
# *************************** 356.038222821
#  33%|███▎      | 416/1261 [02:47<05:19,  2.64it/s]
# *************************** 354.05274659
#  33%|███▎      | 417/1261 [02:47<05:17,  2.66it/s]
# *************************** 352.590107142
#  33%|███▎      | 418/1261 [02:48<05:19,  2.64it/s]
# *************************** 352.130662187
#  33%|███▎      | 419/1261 [02:48<05:14,  2.68it/s]
# *************************** 352.553440959
#  33%|███▎      | 420/1261 [02:48<05:13,  2.68it/s]
# *************************** 354.903858315
#  33%|███▎      | 421/1261 [02:49<05:10,  2.70it/s]
# *************************** 352.199032418
#  33%|███▎      | 422/1261 [02:49<05:12,  2.69it/s]
# *************************** 352.495999418
#  34%|███▎      | 423/1261 [02:49<05:11,  2.69it/s]
# *************************** 351.3978402
#  34%|███▎      | 424/1261 [02:50<05:12,  2.68it/s]
# *************************** 349.721875148
#  34%|███▎      | 425/1261 [02:50<05:09,  2.70it/s]
# *************************** 348.553889974
#  34%|███▍      | 426/1261 [02:51<05:18,  2.62it/s]
# *************************** 346.045403193
#  34%|███▍      | 427/1261 [02:51<05:17,  2.63it/s]
# *************************** 346.919984723
#  34%|███▍      | 428/1261 [02:51<05:14,  2.65it/s]
# *************************** 347.005677251
#  34%|███▍      | 429/1261 [02:52<05:14,  2.65it/s]
# *************************** 347.047051104
#  34%|███▍      | 430/1261 [02:52<05:14,  2.64it/s]
# *************************** 348.213383164
#  34%|███▍      | 431/1261 [02:52<05:14,  2.64it/s]
# *************************** 347.588884217
#  34%|███▍      | 432/1261 [02:53<05:11,  2.66it/s]
# *************************** 347.855863003
#  34%|███▍      | 433/1261 [02:53<05:07,  2.69it/s]
# *************************** 344.361042571
#  34%|███▍      | 434/1261 [02:54<05:10,  2.66it/s]
# *************************** 344.534082132
#  34%|███▍      | 435/1261 [02:54<05:13,  2.64it/s]
# *************************** 343.92262371
#  35%|███▍      | 436/1261 [02:54<05:15,  2.61it/s]
# *************************** 344.033997224
#  35%|███▍      | 437/1261 [02:55<05:11,  2.65it/s]
# *************************** 344.217441673
#  35%|███▍      | 438/1261 [02:55<05:22,  2.55it/s]
# *************************** 342.929590423
#  35%|███▍      | 439/1261 [02:56<05:19,  2.57it/s]
# *************************** 343.016967536
#  35%|███▍      | 440/1261 [02:56<05:13,  2.62it/s]
# *************************** 343.641239659
#  35%|███▍      | 441/1261 [02:56<05:09,  2.65it/s]
# *************************** 343.922243368
#  35%|███▌      | 442/1261 [02:57<05:08,  2.65it/s]
# *************************** 343.360379032
#  35%|███▌      | 443/1261 [02:57<05:07,  2.66it/s]
# *************************** 341.464206977
#  35%|███▌      | 444/1261 [02:57<05:07,  2.66it/s]
# *************************** 341.642483598
#  35%|███▌      | 445/1261 [02:58<05:26,  2.50it/s]
# *************************** 337.69203247
#  35%|███▌      | 446/1261 [02:58<06:22,  2.13it/s]
# *************************** 336.861094132
#  35%|███▌      | 447/1261 [02:59<05:56,  2.28it/s]
# *************************** 337.639554396
#  36%|███▌      | 448/1261 [02:59<05:39,  2.39it/s]
# *************************** 337.576693199
#  36%|███▌      | 449/1261 [03:00<05:33,  2.43it/s]
# *************************** 337.033197636
#  36%|███▌      | 450/1261 [03:00<05:37,  2.40it/s]
# *************************** 335.602027813
#  36%|███▌      | 451/1261 [03:00<05:26,  2.48it/s]
# *************************** 333.873829613
#  36%|███▌      | 452/1261 [03:01<05:17,  2.55it/s]
# *************************** 332.52404499
#  36%|███▌      | 453/1261 [03:01<05:07,  2.63it/s]
# *************************** 330.926514344
#  36%|███▌      | 454/1261 [03:01<05:05,  2.65it/s]
# *************************** 331.655677582
#  36%|███▌      | 455/1261 [03:02<05:03,  2.65it/s]
# *************************** 331.997359247
#  36%|███▌      | 456/1261 [03:02<05:00,  2.68it/s]
# *************************** 333.827968654
#  36%|███▌      | 457/1261 [03:03<04:58,  2.69it/s]
# *************************** 333.914758059
#  36%|███▋      | 458/1261 [03:03<05:00,  2.67it/s]
# *************************** 335.333410198
#  36%|███▋      | 459/1261 [03:03<04:57,  2.69it/s]
# *************************** 337.612624422
#  36%|███▋      | 460/1261 [03:04<04:57,  2.69it/s]
# *************************** 337.234064704
#  37%|███▋      | 461/1261 [03:04<05:01,  2.65it/s]
# *************************** 338.383650937
#  37%|███▋      | 462/1261 [03:04<05:03,  2.64it/s]
# *************************** 336.790355565
#  37%|███▋      | 463/1261 [03:05<05:00,  2.65it/s]
# *************************** 335.946936392
#  37%|███▋      | 464/1261 [03:05<04:57,  2.68it/s]
# *************************** 337.699515383
#  37%|███▋      | 465/1261 [03:06<05:00,  2.65it/s]
# *************************** 336.370490045
#  37%|███▋      | 466/1261 [03:06<05:09,  2.57it/s]
# *************************** 336.097536994
#  37%|███▋      | 467/1261 [03:06<05:12,  2.54it/s]
# *************************** 336.66469412
#  37%|███▋      | 468/1261 [03:07<05:14,  2.52it/s]
# *************************** 338.944477975
#  37%|███▋      | 469/1261 [03:07<05:18,  2.48it/s]
# *************************** 339.590852212
#  37%|███▋      | 470/1261 [03:08<05:47,  2.28it/s]
# *************************** 338.354760689
#  37%|███▋      | 471/1261 [03:08<06:42,  1.96it/s]
# *************************** 340.290637642
#  37%|███▋      | 472/1261 [03:09<06:15,  2.10it/s]
# *************************** 341.618795184
#  38%|███▊      | 473/1261 [03:09<06:12,  2.11it/s]
# *************************** 341.697955998
#  38%|███▊      | 474/1261 [03:10<06:00,  2.18it/s]
# *************************** 341.181926909
#  38%|███▊      | 475/1261 [03:10<05:39,  2.31it/s]
# *************************** 338.855988316
#  38%|███▊      | 476/1261 [03:10<05:21,  2.44it/s]
# *************************** 341.163958459
#  38%|███▊      | 477/1261 [03:11<05:09,  2.53it/s]
# *************************** 341.841666381
#  38%|███▊      | 478/1261 [03:11<05:04,  2.57it/s]
# *************************** 342.41881374
#  38%|███▊      | 479/1261 [03:12<05:10,  2.52it/s]
# *************************** 344.677751906
#  38%|███▊      | 480/1261 [03:12<05:04,  2.57it/s]
# *************************** 345.979924181
#  38%|███▊      | 481/1261 [03:12<05:02,  2.58it/s]
# *************************** 345.706831118
#  38%|███▊      | 482/1261 [03:13<04:59,  2.60it/s]
# *************************** 344.283046584
#  38%|███▊      | 483/1261 [03:13<04:54,  2.65it/s]
# *************************** 343.622969445
#  38%|███▊      | 484/1261 [03:13<04:53,  2.65it/s]
# *************************** 343.67070892
#  38%|███▊      | 485/1261 [03:14<05:01,  2.58it/s]
# *************************** 342.193682787
#  39%|███▊      | 486/1261 [03:14<05:01,  2.57it/s]
# *************************** 342.425414984
#  39%|███▊      | 487/1261 [03:15<04:57,  2.61it/s]
# *************************** 341.920074525
#  39%|███▊      | 488/1261 [03:15<04:52,  2.64it/s]
# *************************** 341.413754653
#  39%|███▉      | 489/1261 [03:15<04:48,  2.67it/s]
# *************************** 343.077570812
#  39%|███▉      | 490/1261 [03:16<04:50,  2.65it/s]
# *************************** 342.313565498
#  39%|███▉      | 491/1261 [03:16<04:50,  2.65it/s]
# *************************** 343.54611236
#  39%|███▉      | 492/1261 [03:17<04:46,  2.69it/s]
# *************************** 343.715719937
#  39%|███▉      | 493/1261 [03:17<04:43,  2.71it/s]
# *************************** 343.647928716
#  39%|███▉      | 494/1261 [03:17<04:45,  2.68it/s]
# *************************** 343.93923112
#  39%|███▉      | 495/1261 [03:18<04:50,  2.63it/s]
# *************************** 344.149375215
#  39%|███▉      | 496/1261 [03:18<04:52,  2.62it/s]
# *************************** 343.19337955
#  39%|███▉      | 497/1261 [03:18<04:47,  2.65it/s]
# *************************** 343.905280196
#  39%|███▉      | 498/1261 [03:19<04:50,  2.62it/s]
# *************************** 344.143300485
#  40%|███▉      | 499/1261 [03:19<04:47,  2.65it/s]
# *************************** 340.637114839
#  40%|███▉      | 500/1261 [03:20<04:44,  2.67it/s]
# *************************** 338.883217605
#  40%|███▉      | 501/1261 [03:20<04:50,  2.62it/s]
# *************************** 339.379038343
#  40%|███▉      | 502/1261 [03:20<04:53,  2.58it/s]
# *************************** 340.927825345
#  40%|███▉      | 503/1261 [03:21<04:55,  2.56it/s]
# *************************** 343.595689646
#  40%|███▉      | 504/1261 [03:21<04:49,  2.61it/s]
# *************************** 343.686094777
#  40%|████      | 505/1261 [03:21<04:45,  2.65it/s]
# *************************** 342.480184283
#  40%|████      | 506/1261 [03:22<04:48,  2.62it/s]
# *************************** 343.150411082
#  40%|████      | 507/1261 [03:22<04:57,  2.54it/s]
# *************************** 342.755933072
#  40%|████      | 508/1261 [03:23<04:50,  2.59it/s]
# *************************** 342.280026211
#  40%|████      | 509/1261 [03:23<04:56,  2.54it/s]
# *************************** 339.980562061
#  40%|████      | 510/1261 [03:23<04:55,  2.54it/s]
# *************************** 339.320062196
#  41%|████      | 511/1261 [03:24<04:48,  2.60it/s]
# *************************** 338.875628075
#  41%|████      | 512/1261 [03:24<04:43,  2.64it/s]
# *************************** 340.081937602
#  41%|████      | 513/1261 [03:25<04:41,  2.66it/s]
# *************************** 342.606022067
#  41%|████      | 514/1261 [03:25<04:44,  2.63it/s]
# *************************** 342.820171252
#  41%|████      | 515/1261 [03:25<04:43,  2.64it/s]
# *************************** 343.81391197
#  41%|████      | 516/1261 [03:26<04:52,  2.55it/s]
# *************************** 342.46088196
# ...
#  73%|███████▎  | 915/1261 [05:57<02:17,  2.51it/s]
# *************************** 358.518070822
#  73%|███████▎  | 916/1261 [05:58<02:16,  2.52it/s]
# *************************** 360.787100538
#  73%|███████▎  | 917/1261 [05:58<02:12,  2.59it/s]
# *************************** 357.724300607
#  73%|███████▎  | 918/1261 [05:58<02:12,  2.60it/s]
# *************************** 356.507788719
#  73%|███████▎  | 919/1261 [05:59<02:10,  2.62it/s]
# *************************** 356.021959559
#  73%|███████▎  | 920/1261 [05:59<02:08,  2.66it/s]
# *************************** 355.682156467
#  73%|███████▎  | 921/1261 [06:00<02:06,  2.68it/s]
# *************************** 356.17794751
#  73%|███████▎  | 922/1261 [06:00<02:12,  2.55it/s]
# *************************** 352.804197953
#  73%|███████▎  | 923/1261 [06:00<02:10,  2.59it/s]
# *************************** 349.821517435
#  73%|███████▎  | 924/1261 [06:01<02:07,  2.64it/s]
# *************************** 346.867309712
#  73%|███████▎  | 925/1261 [06:01<02:05,  2.68it/s]
# *************************** 346.267474647
#  73%|███████▎  | 926/1261 [06:01<02:05,  2.66it/s]
# *************************** 347.754369102
#  74%|███████▎  | 927/1261 [06:02<02:10,  2.56it/s]
# *************************** 348.867498648
#  74%|███████▎  | 928/1261 [06:02<02:06,  2.64it/s]
# *************************** 350.28452772
#  74%|███████▎  | 929/1261 [06:03<02:03,  2.68it/s]
# *************************** 348.153359987
#  74%|███████▍  | 930/1261 [06:03<02:04,  2.66it/s]
# *************************** 345.899382203
#  74%|███████▍  | 931/1261 [06:03<02:03,  2.68it/s]
# *************************** 344.906319349
#  74%|███████▍  | 932/1261 [06:04<02:01,  2.70it/s]
# *************************** 342.672697555
#  74%|███████▍  | 933/1261 [06:04<02:00,  2.73it/s]
# *************************** 343.158085655
#  74%|███████▍  | 934/1261 [06:04<02:01,  2.69it/s]
# *************************** 343.736704932
#  74%|███████▍  | 935/1261 [06:05<02:00,  2.70it/s]
# *************************** 344.185069406
#  74%|███████▍  | 936/1261 [06:05<02:00,  2.70it/s]
# *************************** 348.382926701
#  74%|███████▍  | 937/1261 [06:06<02:00,  2.69it/s]
# *************************** 350.970130268
#  74%|███████▍  | 938/1261 [06:06<02:02,  2.64it/s]
# *************************** 355.050867238
#  74%|███████▍  | 939/1261 [06:06<02:02,  2.63it/s]
# *************************** 357.267302566
#  75%|███████▍  | 940/1261 [06:07<02:01,  2.63it/s]
# *************************** 353.945872461
#  75%|███████▍  | 941/1261 [06:07<01:59,  2.67it/s]
# *************************** 353.950333185
#  75%|███████▍  | 942/1261 [06:07<02:00,  2.64it/s]
# *************************** 352.558817104
#  75%|███████▍  | 943/1261 [06:08<02:03,  2.58it/s]
# *************************** 353.305127485
#  75%|███████▍  | 944/1261 [06:08<02:01,  2.61it/s]
# *************************** 352.639056606
#  75%|███████▍  | 945/1261 [06:09<02:00,  2.62it/s]
# *************************** 354.534170243
#  75%|███████▌  | 946/1261 [06:09<02:02,  2.56it/s]
# *************************** 355.698972744
#  75%|███████▌  | 947/1261 [06:09<02:01,  2.59it/s]
# *************************** 356.337938849
#  75%|███████▌  | 948/1261 [06:10<01:59,  2.61it/s]
# *************************** 357.669701618
#  75%|███████▌  | 949/1261 [06:10<02:03,  2.54it/s]
# *************************** 357.969927265
#  75%|███████▌  | 950/1261 [06:11<02:01,  2.56it/s]
# *************************** 357.970124525
#  75%|███████▌  | 951/1261 [06:11<02:01,  2.56it/s]
# *************************** 357.508186711
#  75%|███████▌  | 952/1261 [06:11<02:01,  2.55it/s]
# *************************** 352.931323723
#  76%|███████▌  | 953/1261 [06:12<02:00,  2.56it/s]
# *************************** 351.331089813
#  76%|███████▌  | 954/1261 [06:12<01:59,  2.57it/s]
# *************************** 348.807993206
#  76%|███████▌  | 955/1261 [06:12<01:57,  2.61it/s]
# *************************** 347.914350363
#  76%|███████▌  | 956/1261 [06:13<01:56,  2.61it/s]
# *************************** 349.394171028
#  76%|███████▌  | 957/1261 [06:13<01:54,  2.66it/s]
# *************************** 350.480178688
#  76%|███████▌  | 958/1261 [06:14<01:57,  2.58it/s]
# *************************** 352.098261331
#  76%|███████▌  | 959/1261 [06:14<01:55,  2.62it/s]
# *************************** 352.449684591
#  76%|███████▌  | 960/1261 [06:14<01:55,  2.61it/s]
# *************************** 355.599471137
#  76%|███████▌  | 961/1261 [06:15<01:53,  2.65it/s]
# *************************** 360.418688293
#  76%|███████▋  | 962/1261 [06:15<01:53,  2.63it/s]
# *************************** 363.185278766
#  76%|███████▋  | 963/1261 [06:16<01:53,  2.62it/s]
# *************************** 368.211843166
#  76%|███████▋  | 964/1261 [06:16<01:56,  2.56it/s]
# *************************** 365.354021459
#  77%|███████▋  | 965/1261 [06:16<01:53,  2.60it/s]
# *************************** 365.034711952
#  77%|███████▋  | 966/1261 [06:17<01:53,  2.60it/s]
# *************************** 367.602237018
#  77%|███████▋  | 967/1261 [06:17<01:51,  2.63it/s]
# *************************** 367.441376823
#  77%|███████▋  | 968/1261 [06:17<01:50,  2.64it/s]
# *************************** 370.257393776
#  77%|███████▋  | 969/1261 [06:18<01:50,  2.64it/s]
# *************************** 370.928920495
#  77%|███████▋  | 970/1261 [06:18<01:51,  2.61it/s]
# *************************** 371.524682966
#  77%|███████▋  | 971/1261 [06:19<01:49,  2.64it/s]
# *************************** 372.604498829
#  77%|███████▋  | 972/1261 [06:19<01:48,  2.66it/s]
# *************************** 374.199382735
#  77%|███████▋  | 973/1261 [06:19<01:47,  2.68it/s]
# *************************** 373.376193113
#  77%|███████▋  | 974/1261 [06:20<01:49,  2.62it/s]
# *************************** 374.403146261
#  77%|███████▋  | 975/1261 [06:20<01:48,  2.63it/s]
# *************************** 379.996339592
#  77%|███████▋  | 976/1261 [06:20<01:48,  2.63it/s]
# *************************** 378.030603537
#  77%|███████▋  | 977/1261 [06:21<01:47,  2.65it/s]
# *************************** 377.621565994
#  78%|███████▊  | 978/1261 [06:21<01:47,  2.63it/s]
# *************************** 378.114945367
#  78%|███████▊  | 979/1261 [06:22<01:47,  2.64it/s]
# *************************** 377.772652057
#  78%|███████▊  | 980/1261 [06:22<01:48,  2.59it/s]
# *************************** 377.849626374
#  78%|███████▊  | 981/1261 [06:22<01:46,  2.62it/s]
# *************************** 379.857785508
#  78%|███████▊  | 982/1261 [06:23<01:48,  2.58it/s]
# *************************** 380.993104682
#  78%|███████▊  | 983/1261 [06:23<01:46,  2.62it/s]
# *************************** 388.292443685
#  78%|███████▊  | 984/1261 [06:24<01:44,  2.65it/s]
# *************************** 385.844123258
#  78%|███████▊  | 985/1261 [06:24<01:43,  2.67it/s]
# *************************** 387.325358894
#  78%|███████▊  | 986/1261 [06:24<01:47,  2.56it/s]
# *************************** 388.805495927
#  78%|███████▊  | 987/1261 [06:25<01:45,  2.59it/s]
# *************************** 392.100748873
#  78%|███████▊  | 988/1261 [06:25<01:47,  2.54it/s]
# *************************** 392.841980821
#  78%|███████▊  | 989/1261 [06:25<01:45,  2.59it/s]
# *************************** 386.259209116
#  79%|███████▊  | 990/1261 [06:26<01:44,  2.60it/s]
# *************************** 377.910041726
#  79%|███████▊  | 991/1261 [06:26<01:43,  2.60it/s]
# *************************** 372.536408305
#  79%|███████▊  | 992/1261 [06:27<01:42,  2.62it/s]
# *************************** 366.885291218
#  79%|███████▊  | 993/1261 [06:27<01:41,  2.65it/s]
# *************************** 364.869263823
#  79%|███████▉  | 994/1261 [06:27<01:41,  2.64it/s]
# *************************** 366.880784049
#  79%|███████▉  | 995/1261 [06:28<01:45,  2.52it/s]
# *************************** 372.495788867
#  79%|███████▉  | 996/1261 [06:28<01:43,  2.57it/s]
# *************************** 383.211698238
#  79%|███████▉  | 997/1261 [06:29<01:42,  2.58it/s]
# *************************** 383.740651751
#  79%|███████▉  | 998/1261 [06:29<01:41,  2.59it/s]
# *************************** 378.994679817
#  79%|███████▉  | 999/1261 [06:29<01:39,  2.63it/s]
# *************************** 368.981491214
#  79%|███████▉  | 1000/1261 [06:30<01:41,  2.57it/s]
# *************************** 362.106504541
#  79%|███████▉  | 1001/1261 [06:30<01:40,  2.59it/s]
# *************************** 354.151016493
#  79%|███████▉  | 1002/1261 [06:31<01:51,  2.33it/s]
# *************************** 343.94009746
#  80%|███████▉  | 1003/1261 [06:31<01:59,  2.15it/s]
# *************************** 337.735910696
#  80%|███████▉  | 1004/1261 [06:32<01:52,  2.28it/s]
# *************************** 334.061104975
#  80%|███████▉  | 1005/1261 [06:32<01:53,  2.25it/s]
# *************************** 330.356248842
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-be7e53616cd2> in <module>()
#       2 clip1 = VideoFileClip("project_video.mp4")
#       3 white_clip = clip1.fl_image(pipeline_predict_lanes) #NOTE: this function expects color images!!
# ----> 4 get_ipython().magic('time white_clip.write_videofile(white_output, audio=False)')
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-59> in time(self, line, cell, local_ns)
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1174         if mode=='eval':
#    1175             st = clock2()
# -> 1176             out = eval(code, glob, local_ns)
#    1177             end = clock2()
#    1178         else:
#
# <timed eval> in <module>()
#
# <decorator-gen-172> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-171> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     135              for (k,v) in k.items()}
#     136
# --> 137     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-170> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params)
#     337                            audiofile = audiofile,
#     338                            verbose=verbose, threads=threads,
# --> 339                            ffmpeg_params=ffmpeg_params)
#     340
#     341         if remove_temp and make_audio:
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params)
#     202
#     203     for t,frame in clip.iter_frames(progress_bar=True, with_times=True,
# --> 204                                     fps=fps, dtype="uint8"):
#     205         if withmask:
#     206             mask = (255*clip.mask.get_frame(t))
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/tqdm/_tqdm.py in __iter__(self)
#     814 """, fp_write=getattr(self.fp, 'write', sys.stderr.write))
#     815
# --> 816             for obj in iterable:
#     817                 yield obj
#     818                 # Update and print the progressbar.
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/Clip.py in generator()
#     471             for t in np.arange(0, self.duration, 1.0/fps):
#     472
# --> 473                 frame = self.get_frame(t)
#     474
#     475                 if (dtype is not None) and (frame.dtype != dtype):
#
# <decorator-gen-135> in get_frame(self, t)
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/Clip.py in get_frame(self, t)
#      93                 return frame
#      94         else:
# ---> 95             return self.make_frame(t)
#      96
#      97     def fl(self, fun, apply_to=[] , keep_duration=True):
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/Clip.py in <lambda>(t)
#     134
#     135         #mf = copy(self.make_frame)
# --> 136         newclip = self.set_make_frame(lambda t: fun(self.get_frame, t))
#     137
#     138         if not keep_duration:
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/moviepy/video/VideoClip.py in <lambda>(gf, t)
#     512         `get_frame(t)` by another frame,  `image_func(get_frame(t))`
#     513         """
# --> 514         return self.fl(lambda gf, t: image_func(gf(t)), apply_to)
#     515
#     516     # --------------------------------------------------------------
#
# <ipython-input-11-2f4e855c8915> in pipeline_predict_lanes(input_image, showMe)
#      79     hotpixels_log = lanes.run_sliding_window(centroid_starter_left[0], centroid_starter_right[0])
#      80     fit_left = lanes.polynomial_fit(hotpixels_log['left'])
# ---> 81     fit_right = lanes.polynomial_fit(hotpixels_log['right'])
#      82     #Get predicted lanes position as a function of height
#      83     var_pts = np.linspace(0, warped_img.shape[0]-1, num=warped_img.shape[0]) #x-axis (height) points
#
# <ipython-input-4-aa66e199eb99> in polynomial_fit(self, data)
#      21         data: dictionary with x and y values {'var':[], 'output':[]}
#      22         '''
# ---> 23         a2, a1, a0 = np.polyfit(data['var'], data['output'], 2)
#      24         return {'a0': a0, 'a1': a1, 'a2': a2}
#      25
#
# /Users/jmlbeaujour/anaconda/lib/python3.5/site-packages/numpy/lib/polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     557         raise TypeError("expected 1D vector for x")
#     558     if x.size == 0:
# --> 559         raise TypeError("expected non-empty vector for x")
#     560     if y.ndim < 1 or y.ndim > 2:
#     561         raise TypeError("expected 1D or 2D array for y")
#
# TypeError: expected non-empty vector for x
